# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

from agents import Agent, Runner, function_tool, ItemHelpers

@function_tool
def get_weather(city: str):
    print(city)
    return "30 degrees"

agent = Agent(
    name="Assistant Agent",
    instructions="You are a helpful assistant. Use tools when needed to answer questions.",
    tools=[get_weather],
)

stream = Runner.run_streamed(agent, "Hello how are you? What is the weather in the capital of Spain?")
async for event in stream.stream_events():
    if event.type == "raw_response_event":
        continue
    elif event.type == "agent_updated_stream_event":
        print("Agent updated to", event.new_agent.name)
    elif event.type == "run_item_stream_event":
        if event.item.type == "tool_call_item":
            print(event.item.raw_item.to_dict())
        elif event.item.type == "tool_call_output_item":
            print(event.item.output)
        elif event.item.type == "message_output_item":
            print(ItemHelpers.text_message_output(event.item))
    print("="*20)
# Out:
# Agent updated to Assistant Agent
# ====================
# {'arguments': '{"city":"Madrid"}', 'call_id': 'call_6fX7bnm6uRU5Q481qToFsc2c', 'name': 'get_weather', 'type': 'function_call', 'id': 'fc_057ffbeae5b7253d0069029d78c61481a2a9d689f95984337e', 'status': 'completed'}
# ====================
# Madrid
# 30 degrees
# ====================
# Hello! I'm here to help. The weather in Madrid, the capital of Spain, is currently 30 degrees. If you need more details or have other questions, feel free to ask!
# ====================

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

from agents import Agent, Runner, function_tool, ItemHelpers

@function_tool
def get_weather(city: str):
    print(city)
    return "30 degrees"

agent = Agent(
    name="Assistant Agent",
    instructions="You are a helpful assistant. Use tools when needed to answer questions.",
    tools=[get_weather],
)

message =""
args = ""

stream = Runner.run_streamed(agent, "Hello how are you? What is the weather in the capital of Korea?")
async for event in stream.stream_events():
    if event.type == "raw_response_event":
        event_type = event.data.type
        if event_type == "response.output_text.delta":
            message += event.data.delta
            print(message)
        elif event_type == "response.function_call_arguments.delta":
            args += event.data.delta
            print(args)
        elif event_type =="response.complete":
            message = ""
            args = ""
# Out:
# {"
# {"city
# {"city":"
# {"city":"Se
# {"city":"Seoul
# {"city":"Seoul"}
# Seoul
# Hello
# Hello!
# Hello! I'm
# Hello! I'm doing
# Hello! I'm doing well
# Hello! I'm doing well,
# Hello! I'm doing well, thank
# Hello! I'm doing well, thank you
# Hello! I'm doing well, thank you.
# Hello! I'm doing well, thank you. The
# Hello! I'm doing well, thank you. The weather
# Hello! I'm doing well, thank you. The weather in
# Hello! I'm doing well, thank you. The weather in Seoul
# Hello! I'm doing well, thank you. The weather in Seoul,
# Hello! I'm doing well, thank you. The weather in Seoul, the
# Hello! I'm doing well, thank you. The weather in Seoul, the capital
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea,
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea, is
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea, is currently
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea, is currently
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea, is currently 30
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea, is currently 30 degrees
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea, is currently 30 degrees Celsius
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea, is currently 30 degrees Celsius.
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea, is currently 30 degrees Celsius. Let
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea, is currently 30 degrees Celsius. Let me
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea, is currently 30 degrees Celsius. Let me know
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea, is currently 30 degrees Celsius. Let me know if
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea, is currently 30 degrees Celsius. Let me know if you
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea, is currently 30 degrees Celsius. Let me know if you need
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea, is currently 30 degrees Celsius. Let me know if you need more
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea, is currently 30 degrees Celsius. Let me know if you need more details
# Hello! I'm doing well, thank you. The weather in Seoul, the capital of South Korea, is currently 30 degrees Celsius. Let me know if you need more details!
